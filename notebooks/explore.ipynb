# %% [markdown]
# ### Exploring the built environment/SDCI datasets

# %%
# Find all *.csv files in the data/ directory. Load each into a pandas DataFrame,
# and create a dictionary mapping filenames (without extension) to DataFrames.

import pandas as pd
import os
data_dir = '../data'
dataframes = {}
for filename in os.listdir(data_dir):
    if filename.endswith('.jsonl'):
        filepath = os.path.join(data_dir, filename)
        df_name = os.path.splitext(filename)[0]
        dataframes[df_name] = pd.read_json(filepath, lines=True)

# Now `dataframes` is a dictionary where keys are filenames without extensions
# and values are the corresponding pandas DataFrames.
for k in dataframes.keys():
    print(k)
# Out:
# issued_building_permits
# land_use_permits
# plan_reviews
# trade_permits
# plan_comments
# electrical_permits
# building_permits

# %%
# Let's take a look at the building_permits DataFrame
building_permits_df = dataframes['building_permits']

# How many rows and columns does it have?
print(building_permits_df.shape)  # (number of rows, number of columns)

# How many have applieddate in every year since 2000?
for year in range(2000, 2026):
    applied_year = building_permits_df[building_permits_df['applieddate'].fillna('').str.startswith(str(year))]
    print(f"{year}: {len(applied_year)}")
# Out:
# (185376, 40)
# 2000: 24
# 2001: 38
# 2002: 83
# 2003: 171
# 2004: 392
# 2005: 3149
# 2006: 8316
# 2007: 7634
# 2008: 6353
# 2009: 4870
# 2010: 5191
# 2011: 5582
# 2012: 6037
# 2013: 7482
# 2014: 7562
# 2015: 8230
# 2016: 8416
# 2017: 8657
# 2018: 8403
# 2019: 7583
# 2020: 6579
# 2021: 6969
# 2022: 6853
# 2023: 5596
# 2024: 6087
# 2025: 5329

# %%
# Print the first few rows to inspect, and don't truncate columns or wrap.
# Display all columns.
# Print the first few rows to inspect, and don't truncate columns or wrap.
# Display all columns.
with pd.option_context('display.max_columns', None, 'display.width', None, 'display.max_colwidth', None):
    display(building_permits_df.head())

# How many completed permits are there? (statuscurrent is "Completed")
completed_permits = building_permits_df[building_permits_df['statuscurrent'] == 'Completed']
print(f"Number of completed permits: {len(completed_permits)}")

# Take a look at top types

top_permit_types = building_permits_df['permittypemapped'].value_counts()
print("\n--------------------------------")
print("Top most common permit types among completed permits:")
print(top_permit_types)

top_permit_desc = building_permits_df['permittypedesc'].value_counts()
print("\n--------------------------------")
print("Top most common permit desc among completed permits:")
print(top_permit_desc)

top_permit_classes = building_permits_df['permitclass'].value_counts()
print("\n--------------------------------")
print("Top 10 most common permit classes:")
print(top_permit_classes)

top_permit_class_mapped = building_permits_df['permitclassmapped'].value_counts()
print("\n--------------------------------")
print("Top 10 most common permit classes:")
print(top_permit_class_mapped)
# Out:
#     permitnum           permitclass permitclassmapped  \
# 0  3001618-EX  Single Family/Duplex       Residential
# 1  3002714-EX  Single Family/Duplex       Residential
# 2  3003172-EX           Multifamily       Residential
# 3  3003255-EX           Multifamily       Residential
# 4  3003258-EX                   N/A               N/A
#
#                                                    permittypemapped  \
# 0  ECA and Shoreline Exemption/Street Improvement Exception Request
# 1  ECA and Shoreline Exemption/Street Improvement Exception Request
# 2  ECA and Shoreline Exemption/Street Improvement Exception Request
# 3  ECA and Shoreline Exemption/Street Improvement Exception Request
# 4  ECA and Shoreline Exemption/Street Improvement Exception Request
#
#                             permittypedesc  \
# 0  Environmentally Critical Area Exemption
# 1  Environmentally Critical Area Exemption
# 2  Environmentally Critical Area Exemption
# 3  Environmentally Critical Area Exemption
# 4                      Shoreline Exemption
#
#                                                                                                                                                                                                                                                                                                                                                          description  \
# 0                                                            Exception/Exemption Request for: PROJECT CANCELLED -- 9/15/2011 SGP.Land Use Application to subdivide one parcel into two parcels of land in an environmentally critical area.  Proposed parcel sizes are: A) 22 221 sq. ft. and B) 10 684 sq. ft.   Existing structure on proposed parcel A to remain.
# 1                                                                                                                                                                                  Exception/Exemption Request for: PROJECT CANCELLED 12/10/10 -- SEPA-Construct two new duplex townhouse buildings  each unit with enclosed garage parking.(ECA EXEMPTION INCLUDED)
# 2  Exception/Exemption Request for: Shoreline Substantial Development Permit to allow one 4-story townhouse structure and six 3-story townhouse structures for a total of 21 units in an environmentally critical area. Parking for 28 vehicles to be provided within the structures. Project includes 8 150 cu. yds. of grading. Existing structures to be removed.
# 3                                                                         Exception/Exemption Request for: Land use approval to establish use for two 2-unit townhouse structures & one 5-unit townhouse structure for a total of 9 units  in an environmentally critical area. Parking will be located within the structures. Existing structures to be demolished.
# 4                                                                                                                                                                          Exception/Exemption Request for: CANCELLED 1/10/2011 -- sepa for landslide restoration & prevention & retaining wall construction (SEE HWT notes).  related construction project #6066109
#
#    housingunits statuscurrent  relatedmup     originaladdress1 originalcity  \
# 0             0      Canceled  3001618-LU    6044 UPLAND TER S      SEATTLE
# 1             0      Canceled  3002714-LU   1001 STURGUS AVE S      SEATTLE
# 2             0     Completed  3003172-LU  2808 FAIRVIEW AVE E      SEATTLE
# 3             0     Completed  3003255-LU     2402 W BOSTON ST      SEATTLE
# 4             0      Canceled  3003258-LU    2912 NW ESPLANADE      SEATTLE
#
#   originalstate  originalzip  \
# 0            WA      98118.0
# 1            WA      98144.0
# 2            WA      98102.0
# 3            WA      98199.0
# 4            WA      98117.0
#
#                                                                                           link  \
# 0  {'url': 'https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=3001618-EX'}
# 1  {'url': 'https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=3002714-EX'}
# 2  {'url': 'https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=3003172-EX'}
# 3  {'url': 'https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=3003255-EX'}
# 4  {'url': 'https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=3003258-EX'}
#
#     latitude   longitude  \
# 0  47.547860 -122.264886
# 1  47.593697 -122.314278
# 2  47.646023 -122.326585
# 3  47.638600 -122.388333
# 4  47.700164 -122.394676
#
#                                                    location1  \
# 0  {'latitude': '47.54786009', 'longitude': '-122.26488649'}
# 1   {'latitude': '47.5936975', 'longitude': '-122.31427847'}
# 2  {'latitude': '47.64602266', 'longitude': '-122.32658489'}
# 3  {'latitude': '47.63859999', 'longitude': '-122.38833307'}
# 4   {'latitude': '47.70016386', 'longitude': '-122.3946755'}
#
#    dependentbuilding housingcategory  daysoutcorrections  numberreviewcycles  \
# 0                  0             N/A                 NaN                 NaN
# 1                  0             N/A                 NaN                 NaN
# 2                  0             N/A                 0.0                 0.0
# 3                  0             N/A                 0.0                 0.0
# 4                  0             N/A                 NaN                 NaN
#
#   contractorcompanyname  housingunitsremoved  housingunitsadded  \
# 0                   NaN                  NaN                NaN
# 1                   NaN                  NaN                NaN
# 2                   NaN                  NaN                NaN
# 3                   NaN                  NaN                NaN
# 4                   NaN                  NaN                NaN
#
#    estprojectcost applieddate issueddate expiresdate completeddate zoning  \
# 0             NaN         NaN        NaN         NaN           NaN    NaN
# 1             NaN         NaN        NaN         NaN           NaN    NaN
# 2             NaN         NaN        NaN         NaN           NaN    NaN
# 3             NaN         NaN        NaN         NaN           NaN    NaN
# 4             NaN         NaN        NaN         NaN           NaN    NaN
#
#   dwellingunittype  standardplan parentpermitnum readytoissuedate  \
# 0              NaN           NaN             NaN              NaN
# 1              NaN           NaN             NaN              NaN
# 2              NaN           NaN             NaN              NaN
# 3              NaN           NaN             NaN              NaN
# 4              NaN           NaN             NaN              NaN
#
#    totaldaysplanreview  daysplanreviewcity planreviewcompletedate  \
# 0                  NaN                 NaN                    NaN
# 1                  NaN                 NaN                    NaN
# 2                  NaN                 NaN                    NaN
# 3                  NaN                 NaN                    NaN
# 4                  NaN                 NaN                    NaN
#
#    daysinitialplanreview initialreviewcompletedate  daysissuepermitcity
# 0                    NaN                       NaN                  NaN
# 1                    NaN                       NaN                  NaN
# 2                    NaN                       NaN                  NaN
# 3                    NaN                       NaN                  NaN
# 4                    NaN                       NaN                  NaN
# Number of completed permits: 128623
#
# --------------------------------
# Top most common permit types among completed permits:
# permittypemapped
# Building                                                            148993
# ECA and Shoreline Exemption/Street Improvement Exception Request     18195
# Demolition                                                           15466
# Roof                                                                  1708
# Grading                                                               1014
# Name: count, dtype: int64
#
# --------------------------------
# Top most common permit desc among completed permits:
# permittypedesc
# Addition/Alteration                        107616
# New                                         30548
# Environmentally Critical Area Exemption     11378
# Demolition                                   9047
# Tenant Improvment                            4744
# Shoreline Exemption                          3534
# Relief from Prohibition on Steep Slope       1395
# Temporary                                    1063
# Shoreline Permit Exemption                    867
# Curb Cut                                      789
# Street Improvement Exception                  669
# Change of Use Only - No Construction          440
# NONE                                          386
# Tenant Improvement Pre-Approval               288
# Modification to Submittal Requirements        178
# ECA Small Project Waiver                      143
# Deconstruction                                 42
# Relocation                                     23
# Name: count, dtype: int64
#
# --------------------------------
# Top 10 most common permit classes:
# permitclass
# Single Family/Duplex    107193
# Commercial               41881
# Multifamily              21129
# N/A                       6799
# Institutional             5497
# Industrial                2450
# Vacant Land                427
# Name: count, dtype: int64
#
# --------------------------------
# Top 10 most common permit classes:
# permitclassmapped
# Residential        128322
# Non-Residential     50255
# N/A                  6799
# Name: count, dtype: int64

# %%
import folium
from folium.plugins import MarkerCluster
# from IPython.display import display, HTML

# Map all permits that were applied for in 2025
applied_2025 = building_permits_df[building_permits_df['applieddate'].fillna('').str.startswith('2025')]
print(f"\nNumber of permits applied for in 2025: {len(applied_2025)}")

# Create a folium map centered around Seattle
seattle_map = folium.Map(location=[47.6062, -122.3321], zoom_start=10, tiles='CartoDB positron')
marker_cluster = MarkerCluster().add_to(seattle_map)

# Add markers for each permit
for idx, row in applied_2025.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    permit_class = row['permitclass']
    link_url = row.get("link", {}).get("url", "#")
    if pd.notnull(lat) and pd.notnull(lon) and permit_class == 'Commercial':
        folium.Marker(
            location=[lat, lon],
            popup=f"Permit Type: {row['permittypemapped']}<br>Address: {row['originaladdress1']}<br><a href='{link_url}' target='_blank'>View Permit</a>",
        ).add_to(marker_cluster)

# Display the map
seattle_map
# Out:
# Number of permits applied for in 2025: 5329
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfce47be17d411211f40231d1de2c988 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfce47be17d411211f40231d1de2c988&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfce47be17d411211f40231d1de2c988 = L.map(
#                 &quot;map_dfce47be17d411211f40231d1de2c988&quot;,
#                 {
#                     center: [47.6062, -122.3321],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1906f6a0502988f4d3d0337227e3bfc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1906f6a0502988f4d3d0337227e3bfc.addTo(map_dfce47be17d411211f40231d1de2c988);
#
#
#             var marker_cluster_86cde16ca4678753eb36e7b20b34dd25 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_68ef8ec8043d7194ec2195dd83533a5c = L.marker(
#                 [47.52407658, -122.26587356],
#                 {
# }
#             ).addTo(marker_cluster_86cde16ca4678753eb36e7b20b34dd25);
#
#
#         var popup_382d97c8973d0aaa9aae30c9a2dac5cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f070a6dd2139352bc4a9a71530b75a9 = $(`&lt;div id=&quot;html_9f070a6dd2139352bc4a9a71530b75a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Permit Type: Demolition&lt;br&gt;Address: 8815 SEWARD PARK AVE S&lt;br&gt;&lt;a href=&#x27;https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=6822319-DM&#x27; target=&#x27;_blank&#x27;&gt;View Permit&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_382d97c8973d0aaa9aae30c9a2dac5cd.setContent(html_9f070a6dd2139352bc4a9a71530b75a9);
#
#
#
#         marker_68ef8ec8043d7194ec2195dd83533a5c.bindPopup(popup_382d97c8973d0aaa9aae30c9a2dac5cd)
#         ;
#
#
#
#
#             var marker_b738b35e274e29eb7a8500c8b6feb15f = L.marker(
#                 [47.57609364, -122.30987586],
#                 {
# }
#             ).addTo(marker_cluster_86cde16ca4678753eb36e7b20b34dd25);
#
#
#         var popup_bc490a76eafcc2a0ce5099f951e6c5d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b49f8018fed04b5c6b0d16d50c8d1403 = $(`&lt;div id=&quot;html_b49f8018fed04b5c6b0d16d50c8d1403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Permit Type: Building&lt;br&gt;Address: 3031 BEACON AVE S&lt;br&gt;&lt;a href=&#x27;https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=6850465-CN&#x27; target=&#x27;_blank&#x27;&gt;View Permit&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_bc490a76eafcc2a0ce5099f951e6c5d9.setContent(html_b49f8018fed04b5c6b0d16d50c8d1403);
#
#
#
#         marker_b738b35e274e29eb7a8500c8b6feb15f.bindPopup(popup_bc490a76eafcc2a0ce5099f951e6c5d9)
#         ;
#
#
#
#
#             var marker_ca18128ac99f9dc37185fa70a6accee8 = L.marker(
#                 [47.61951135, -122.33696288],
#                 {
# }
#             ).addTo(marker_cluster_86cde16ca4678753eb36e7b20b34dd25);
#
#
#         var popup_12a2fd1c5fee79c02bda9e70e1b7176e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73a493f91878df62129678bcdd77eaad = $(`&lt;div id=&quot;html_73a493f91878df62129678bcdd77eaad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Permit Type: Building&lt;br&gt;Address: 124 TERRY AVE N&lt;br&gt;&lt;a href=&#x27;https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=6974151-CN&#x27; target=&#x27;_blank&#x27;&gt;View Permit&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_12a2fd1c5fee79c02bda9e70e1b7176e.setContent(html_73a493f91878df62129678bcdd77eaad);
#
#
#
#         marker_ca18128ac99f9dc37185fa70a6accee8.bindPopup(popup_12a2fd1c5fee79c02bda9e70e1b7176e)
#         ;
#
#
#
#
#             var marker_5f32fdf8f0712fba563bd7d2be1aa339 = L.marker(
#                 [47.67397023, -122.31705155],
